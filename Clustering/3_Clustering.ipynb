# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import geopandas as gpd
import pandas as pd

# %%
data = gpd.read_file("Shapefile/Accidents_with_Dual_Dist.shp")
data.head()
# Out:
#    OBJECTID  OBJECTID_1 Cod_Uniq_F Cod_Uniq Name_Hoze Cod_Hoze Name_Mehva  \
# 0       149         0.0       None     None      None     None       None
# 1       150         0.0       None     None      None     None       None
# 2       151         0.0       None     None      None     None       None
# 3       152         0.0       None     None      None     None       None
# 4       153         0.0       None     None      None     None       None
#
#      Y    X Band_Raft_  ... Mahdode_Ab  Mahdode_Ma Mahdode_Sh  Onvan_File  \
# 0  0.0  0.0       None  ...        0.0         0.0        0.0        None
# 1  0.0  0.0       None  ...        0.0         0.0        0.0        None
# 2  0.0  0.0       None  ...        0.0         0.0        0.0        None
# 3  0.0  0.0       None  ...        0.0         0.0        0.0        None
# 4  0.0  0.0       None  ...        0.0         0.0        0.0        None
#
#             X_            Y_   ID   Distance Dual_Dista  \
# 0  562061.4358  4.005229e+06 -1.0   0.000000        0.0
# 1  562056.1959  4.005130e+06 -1.0  99.412989        0.0
# 2  562073.1524  4.005031e+06 -1.0  99.846558        0.0
# 3  562106.7657  4.004937e+06 -1.0  99.851346        0.0
# 4  562139.5274  4.004843e+06 -1.0  99.979818        0.0
#
#                          geometry
# 0  POINT (562061.436 4005229.099)
# 1  POINT (562056.196 4005129.824)
# 2  POINT (562073.152 4005031.428)
# 3  POINT (562106.766 4004937.404)
# 4  POINT (562139.527 4004842.944)
#
# [5 rows x 119 columns]

# %%
# Data cleaning
Acc_data = data[data["ID"] != -1]
Acc_data.head()
# Out:
#     OBJECTID  OBJECTID_1 Cod_Uniq_F  Cod_Uniq    Name_Hoze Cod_Hoze  \
# 12       148     19441.0     M12-3R  M12-406B  حوزه سبزوار     None
# 17        17      2949.0       None    M12-5R  حوزه سبزوار     None
# 20        71     10301.0       None  M12-404B  حوزه سبزوار     None
# 31         7      2170.0       None    M12-9R  حوزه سبزوار     None
# 33       101     15608.0       None  M12-400B  حوزه سبزوار     None
#
#        Name_Mehva             Y            X     Band_Raft_  ... Mahdode_Ab  \
# 12  سبزوار-بردسكن  4.004186e+06  562530.3841  بردسكن-سبزوار  ...        0.0
# 17  سبزوار-بردسكن  4.003849e+06  562684.6853  سبزوار-بردسكن  ...        1.0
# 20  سبزوار-بردسكن  4.003634e+06  562715.9041  بردسكن-سبزوار  ...        0.0
# 31  سبزوار-بردسكن  4.002828e+06  562946.3556  سبزوار-بردسكن  ...        1.0
# 33  سبزوار-بردسكن  4.002734e+06  563040.1760  بردسكن-سبزوار  ...        0.0
#
#     Mahdode_Ma Mahdode_Sh  Onvan_File           X_            Y_   ID  \
# 12         0.0        1.0      سبزوار  562530.3841  4.004186e+06  1.0
# 17         0.0        1.0        None  562684.6853  4.003849e+06  2.0
# 20         0.0        1.0        None  562715.9041  4.003634e+06  3.0
# 31         0.0        1.0        None  562946.3556  4.002828e+06  4.0
# 33         0.0        1.0        None  563062.4010  4.002767e+06  5.0
#
#      Distance  Dual_Dista                        geometry
# 12  65.816968    0.000000  POINT (562530.384 4004186.076)
# 17  40.852908  375.292765  POINT (562684.685 4003848.858)
# 20  58.634003  217.787079  POINT (562715.904 4003634.152)
# 31  24.762633  967.719574  POINT (562946.356 4002827.756)
# 33  55.812578  131.195831  POINT (563062.401 4002766.730)
#
# [5 rows x 119 columns]

# %%
X = Acc_data.geometry.apply(lambda coordinate: list(coordinate.coords[0]))
X = np.array(X.tolist())
X
# Out:
# array([[ 562530.3841, 4004186.0758],
#        [ 562684.6853, 4003848.8579],
#        [ 562715.9041, 4003634.1523],
#        [ 562946.3556, 4002827.7558],
#        [ 563062.401 , 4002766.7305],
#        [ 563882.0369, 4002348.5041],
#        [ 564233.7286, 4001680.7255],
#        [ 565331.2788, 4000128.8828],
#        [ 565759.1708, 3999694.4768],
#        [ 565843.1046, 3999588.4867],
#        [ 565970.94  , 3999402.08  ],
#        [ 566295.9536, 3998946.0816],
#        [ 566359.2577, 3998856.7717],
#        [ 566625.6318, 3998521.2133],
#        [ 566723.5796, 3998395.3193],
#        [ 567241.6349, 3997795.0471],
#        [ 567310.6079, 3997700.674 ],
#        [ 567401.1899, 3997592.2941],
#        [ 567419.2857, 3997579.8003],
#        [ 567458.6818, 3997528.3384],
#        [ 567593.8788, 3997373.1608],
#        [ 567732.4282, 3997205.378 ],
#        [ 567929.4962, 3996971.8037],
#        [ 568144.1997, 3996722.3484],
#        [ 571024.9928, 3994232.8702],
#        [ 571359.1067, 3994006.2313],
#        [ 571598.6538, 3993748.2425],
#        [ 571658.6028, 3993685.1401],
#        [ 571790.8999, 3993540.7918],
#        [ 574009.8695, 3991170.6194],
#        [ 574220.4281, 3990944.2065],
#        [ 574311.3959, 3990839.4645],
#        [ 574429.4372, 3990668.5287],
#        [ 574913.8499, 3989884.596 ],
#        [ 576588.5389, 3987127.8897],
#        [ 576754.4877, 3986855.1347],
#        [ 577312.0324, 3985960.4779],
#        [ 577546.702 , 3985577.4226],
#        [ 578367.8268, 3984222.8099],
#        [ 578777.5414, 3983599.1178],
#        [ 578900.9731, 3983487.733 ],
#        [ 579116.4503, 3983308.5129],
#        [ 579966.2316, 3982578.5353],
#        [ 580424.323 , 3982190.1537],
#        [ 581004.332 , 3981684.2681],
#        [ 581910.8521, 3980912.4905],
#        [ 583504.126 , 3979713.0721],
#        [ 583995.39  , 3979258.979 ],
#        [ 584020.9651, 3979230.5667],
#        [ 584234.166 , 3978995.3412],
#        [ 584483.9368, 3978720.7039],
#        [ 584483.9368, 3978720.7039],
#        [ 584729.8452, 3978456.4105],
#        [ 585183.7694, 3977565.7979],
#        [ 585251.4623, 3977355.0725],
#        [ 585301.7849, 3977204.5737],
#        [ 585528.5024, 3976543.3583],
#        [ 585548.1355, 3976480.3813],
#        [ 585562.0325, 3976442.9239],
#        [ 585595.0453, 3976346.7984],
#        [ 586234.8757, 3974938.083 ],
#        [ 586361.0381, 3974801.8904],
#        [ 586682.7081, 3974488.9019],
#        [ 586732.5768, 3974439.4747],
#        [ 586805.2307, 3974361.0262],
#        [ 587365.675 , 3973811.5699],
#        [ 587365.675 , 3973811.5699],
#        [ 588718.7969, 3972881.8928],
#        [ 588978.2513, 3972809.1051],
#        [ 589958.7397, 3972328.0983],
#        [ 591649.214 , 3970174.9327],
#        [ 591707.7889, 3969852.0379],
#        [ 591402.6643, 3967030.036 ],
#        [ 590742.0475, 3964893.2857],
#        [ 590683.3985, 3964801.5871],
#        [ 590448.8734, 3963877.2454],
#        [ 589973.8208, 3962841.6972],
#        [ 590170.5104, 3962539.4373],
#        [ 590268.3133, 3962420.9028],
#        [ 590364.7338, 3962295.4047],
#        [ 590485.5036, 3962145.1766],
#        [ 591079.777 , 3961028.8693],
#        [ 591161.5469, 3960675.9674],
#        [ 591176.1126, 3960602.4735],
#        [ 590779.812 , 3960074.5762],
#        [ 590725.2849, 3959981.3745],
#        [ 590462.4967, 3959638.1451],
#        [ 590156.653 , 3959395.6805],
#        [ 590034.7794, 3959265.8286],
#        [ 589692.8682, 3958387.7862],
#        [ 589598.978 , 3958141.3278],
#        [ 589598.978 , 3958141.3278],
#        [ 589348.8386, 3957564.1676],
#        [ 589411.4963, 3957327.8256],
#        [ 589439.2468, 3957218.9997],
#        [ 589525.0439, 3956043.7493],
#        [ 589796.3507, 3955535.0344],
#        [ 590224.7293, 3953084.408 ],
#        [ 590151.137 , 3952683.8195],
#        [ 590103.3102, 3952518.4854],
#        [ 589772.0817, 3950481.4899],
#        [ 589513.5841, 3949319.0943],
#        [ 588970.4466, 3947700.2977],
#        [ 589219.6964, 3947001.8865],
#        [ 589497.3589, 3944984.8457],
#        [ 589510.9011, 3944481.3498],
#        [ 590365.0253, 3942486.0983],
#        [ 590892.9724, 3941215.8371],
#        [ 591207.877 , 3940121.2102],
#        [ 591233.3537, 3937310.4672],
#        [ 591171.0963, 3937047.3109],
#        [ 591886.3531, 3934326.3707],
#        [ 591886.3531, 3934326.3707],
#        [ 592617.7443, 3932588.272 ],
#        [ 594245.7602, 3930130.453 ],
#        [ 594266.03  , 3930000.0229],
#        [ 594307.3776, 3929806.0339],
#        [ 593774.0709, 3928430.2137],
#        [ 592979.9777, 3927251.0741],
#        [ 592455.6586, 3925343.8204],
#        [ 592946.628 , 3924222.8483],
#        [ 592870.5227, 3923555.3975],
#        [ 592817.6424, 3923459.5372],
#        [ 589991.1533, 3918605.6648],
#        [ 589870.7965, 3918129.9672],
#        [ 589859.9179, 3918078.2843],
#        [ 589859.9179, 3918078.2843],
#        [ 589355.4926, 3916676.7043],
#        [ 589418.1477, 3916395.1308],
#        [ 589560.9468, 3915934.9714],
#        [ 589591.1472, 3915816.3419],
#        [ 589469.2875, 3915383.7739],
#        [ 589270.1863, 3915104.4955],
#        [ 589239.1104, 3915057.3543],
#        [ 589217.8597, 3915011.8512],
#        [ 589012.4672, 3914701.2406],
#        [ 588956.9068, 3912982.1816],
#        [ 588810.954 , 3911932.716 ],
#        [ 588751.2362, 3911432.8692],
#        [ 588603.4465, 3910106.3973],
#        [ 588664.3091, 3909009.631 ],
#        [ 588660.2874, 3908747.1318],
#        [ 588684.2391, 3907981.4165],
#        [ 589107.894 , 3905675.5554],
#        [ 590404.633 , 3902637.4673],
#        [ 590477.7632, 3902249.3717],
#        [ 590539.3133, 3901806.9342],
#        [ 590617.6386, 3901405.9516]])

# %%
# Fitting DBSCAN clusterer with eps=200
Clusterer_200 = DBSCAN(eps=200, min_samples=3)
Clusterer_200.fit(X)
Acc_data_lables = pd.Series(Clusterer_200.labels_, index=Acc_data.index, name="Labels_200")

# %%
# Assigning clustered labels to the accident data
Acc_data = Acc_data.merge(Acc_data_lables, left_index=True, right_index=True)
Acc_data.head()
# Out:
#     OBJECTID  OBJECTID_1 Cod_Uniq_F  Cod_Uniq    Name_Hoze Cod_Hoze  \
# 12       148     19441.0     M12-3R  M12-406B  حوزه سبزوار     None
# 17        17      2949.0       None    M12-5R  حوزه سبزوار     None
# 20        71     10301.0       None  M12-404B  حوزه سبزوار     None
# 31         7      2170.0       None    M12-9R  حوزه سبزوار     None
# 33       101     15608.0       None  M12-400B  حوزه سبزوار     None
#
#        Name_Mehva             Y            X     Band_Raft_  ... Mahdode_Ma  \
# 12  سبزوار-بردسكن  4.004186e+06  562530.3841  بردسكن-سبزوار  ...        0.0
# 17  سبزوار-بردسكن  4.003849e+06  562684.6853  سبزوار-بردسكن  ...        0.0
# 20  سبزوار-بردسكن  4.003634e+06  562715.9041  بردسكن-سبزوار  ...        0.0
# 31  سبزوار-بردسكن  4.002828e+06  562946.3556  سبزوار-بردسكن  ...        0.0
# 33  سبزوار-بردسكن  4.002734e+06  563040.1760  بردسكن-سبزوار  ...        0.0
#
#     Mahdode_Sh Onvan_File           X_            Y_   ID   Distance  \
# 12         1.0     سبزوار  562530.3841  4.004186e+06  1.0  65.816968
# 17         1.0       None  562684.6853  4.003849e+06  2.0  40.852908
# 20         1.0       None  562715.9041  4.003634e+06  3.0  58.634003
# 31         1.0       None  562946.3556  4.002828e+06  4.0  24.762633
# 33         1.0       None  563062.4010  4.002767e+06  5.0  55.812578
#
#     Dual_Dista                        geometry  Labels_200
# 12    0.000000  POINT (562530.384 4004186.076)          -1
# 17  375.292765  POINT (562684.685 4003848.858)          -1
# 20  217.787079  POINT (562715.904 4003634.152)          -1
# 31  967.719574  POINT (562946.356 4002827.756)          -1
# 33  131.195831  POINT (563062.401 4002766.730)          -1
#
# [5 rows x 120 columns]

# %%
Clusters_counts = len(set(Acc_data_lables))
print('Number of clusters: {}'.format(Clusters_counts))
# Out:
# Number of clusters: 9

# %%
# Fitting DBSCAN clusterer with eps=300
Clusterer_300 = DBSCAN(eps=300, min_samples=3)
Clusterer_300.fit(Acc_data[["X_","Y_"]])
Acc_data_lables = pd.Series(Clusterer_300.labels_, index=Acc_data.index, name="Labels_300")

# %%
# Assigning clustered labels to the accident data
Acc_data = Acc_data.merge(Acc_data_lables, left_index=True, right_index=True)
Acc_data.head()
# Out:
#     OBJECTID  OBJECTID_1 Cod_Uniq_F  Cod_Uniq    Name_Hoze Cod_Hoze  \
# 12       148     19441.0     M12-3R  M12-406B  حوزه سبزوار     None
# 17        17      2949.0       None    M12-5R  حوزه سبزوار     None
# 20        71     10301.0       None  M12-404B  حوزه سبزوار     None
# 31         7      2170.0       None    M12-9R  حوزه سبزوار     None
# 33       101     15608.0       None  M12-400B  حوزه سبزوار     None
#
#        Name_Mehva             Y            X     Band_Raft_  ... Mahdode_Sh  \
# 12  سبزوار-بردسكن  4.004186e+06  562530.3841  بردسكن-سبزوار  ...        1.0
# 17  سبزوار-بردسكن  4.003849e+06  562684.6853  سبزوار-بردسكن  ...        1.0
# 20  سبزوار-بردسكن  4.003634e+06  562715.9041  بردسكن-سبزوار  ...        1.0
# 31  سبزوار-بردسكن  4.002828e+06  562946.3556  سبزوار-بردسكن  ...        1.0
# 33  سبزوار-بردسكن  4.002734e+06  563040.1760  بردسكن-سبزوار  ...        1.0
#
#     Onvan_File           X_            Y_   ID   Distance  Dual_Dista  \
# 12      سبزوار  562530.3841  4.004186e+06  1.0  65.816968    0.000000
# 17        None  562684.6853  4.003849e+06  2.0  40.852908  375.292765
# 20        None  562715.9041  4.003634e+06  3.0  58.634003  217.787079
# 31        None  562946.3556  4.002828e+06  4.0  24.762633  967.719574
# 33        None  563062.4010  4.002767e+06  5.0  55.812578  131.195831
#
#                           geometry Labels_200  Labels_300
# 12  POINT (562530.384 4004186.076)         -1          -1
# 17  POINT (562684.685 4003848.858)         -1          -1
# 20  POINT (562715.904 4003634.152)         -1          -1
# 31  POINT (562946.356 4002827.756)         -1          -1
# 33  POINT (563062.401 4002766.730)         -1          -1
#
# [5 rows x 121 columns]

# %%
Clusters_counts = len(set(Acc_data_lables))
print('Number of clusters: {}'.format(Clusters_counts))
# Out:
# Number of clusters: 15

# %%
# Fitting DBSCAN clusterer with eps=430
Clusterer_430 = DBSCAN(eps=430, min_samples=3)
Clusterer_430.fit(X)
Acc_data_lables = pd.Series(Clusterer_430.labels_, index=Acc_data.index, name="Labels_430")

# %%
# Assigning clustered labels to the accident data
Acc_data = Acc_data.merge(Acc_data_lables, left_index=True, right_index=True)
Acc_data.head()
# Out:
#     OBJECTID  OBJECTID_1 Cod_Uniq_F  Cod_Uniq    Name_Hoze Cod_Hoze  \
# 12       148     19441.0     M12-3R  M12-406B  حوزه سبزوار     None
# 17        17      2949.0       None    M12-5R  حوزه سبزوار     None
# 20        71     10301.0       None  M12-404B  حوزه سبزوار     None
# 31         7      2170.0       None    M12-9R  حوزه سبزوار     None
# 33       101     15608.0       None  M12-400B  حوزه سبزوار     None
#
#        Name_Mehva             Y            X     Band_Raft_  ... Onvan_File  \
# 12  سبزوار-بردسكن  4.004186e+06  562530.3841  بردسكن-سبزوار  ...     سبزوار
# 17  سبزوار-بردسكن  4.003849e+06  562684.6853  سبزوار-بردسكن  ...       None
# 20  سبزوار-بردسكن  4.003634e+06  562715.9041  بردسكن-سبزوار  ...       None
# 31  سبزوار-بردسكن  4.002828e+06  562946.3556  سبزوار-بردسكن  ...       None
# 33  سبزوار-بردسكن  4.002734e+06  563040.1760  بردسكن-سبزوار  ...       None
#
#              X_            Y_   ID   Distance  Dual_Dista  \
# 12  562530.3841  4.004186e+06  1.0  65.816968    0.000000
# 17  562684.6853  4.003849e+06  2.0  40.852908  375.292765
# 20  562715.9041  4.003634e+06  3.0  58.634003  217.787079
# 31  562946.3556  4.002828e+06  4.0  24.762633  967.719574
# 33  563062.4010  4.002767e+06  5.0  55.812578  131.195831
#
#                           geometry Labels_200 Labels_300  Labels_430
# 12  POINT (562530.384 4004186.076)         -1         -1           0
# 17  POINT (562684.685 4003848.858)         -1         -1           0
# 20  POINT (562715.904 4003634.152)         -1         -1           0
# 31  POINT (562946.356 4002827.756)         -1         -1          -1
# 33  POINT (563062.401 4002766.730)         -1         -1          -1
#
# [5 rows x 122 columns]

# %%
Clusters_counts = len(set(Acc_data_lables))
print('Number of clusters: {}'.format(Clusters_counts))
# Out:
# Number of clusters: 21

# %%
# Fitting DBSCAN clusterer with eps=500
Clusterer_500 = DBSCAN(eps=500, min_samples=3)
Clusterer_500.fit(Acc_data[["X_","Y_"]])
Acc_data_lables = pd.Series(Clusterer_500.labels_, index=Acc_data.index, name="Labels_500")

# %%
# Assigning clustered labels to the accident data
Acc_data = Acc_data.merge(Acc_data_lables, left_index=True, right_index=True)
Acc_data.head()
# Out:
#     OBJECTID  OBJECTID_1 Cod_Uniq_F  Cod_Uniq    Name_Hoze Cod_Hoze  \
# 12       148     19441.0     M12-3R  M12-406B  حوزه سبزوار     None
# 17        17      2949.0       None    M12-5R  حوزه سبزوار     None
# 20        71     10301.0       None  M12-404B  حوزه سبزوار     None
# 31         7      2170.0       None    M12-9R  حوزه سبزوار     None
# 33       101     15608.0       None  M12-400B  حوزه سبزوار     None
#
#        Name_Mehva             Y            X     Band_Raft_  ...           X_  \
# 12  سبزوار-بردسكن  4.004186e+06  562530.3841  بردسكن-سبزوار  ...  562530.3841
# 17  سبزوار-بردسكن  4.003849e+06  562684.6853  سبزوار-بردسكن  ...  562684.6853
# 20  سبزوار-بردسكن  4.003634e+06  562715.9041  بردسكن-سبزوار  ...  562715.9041
# 31  سبزوار-بردسكن  4.002828e+06  562946.3556  سبزوار-بردسكن  ...  562946.3556
# 33  سبزوار-بردسكن  4.002734e+06  563040.1760  بردسكن-سبزوار  ...  563062.4010
#
#               Y_   ID   Distance  Dual_Dista                        geometry  \
# 12  4.004186e+06  1.0  65.816968    0.000000  POINT (562530.384 4004186.076)
# 17  4.003849e+06  2.0  40.852908  375.292765  POINT (562684.685 4003848.858)
# 20  4.003634e+06  3.0  58.634003  217.787079  POINT (562715.904 4003634.152)
# 31  4.002828e+06  4.0  24.762633  967.719574  POINT (562946.356 4002827.756)
# 33  4.002767e+06  5.0  55.812578  131.195831  POINT (563062.401 4002766.730)
#
#    Labels_200 Labels_300 Labels_430  Labels_500
# 12         -1         -1          0           0
# 17         -1         -1          0           0
# 20         -1         -1          0           0
# 31         -1         -1         -1          -1
# 33         -1         -1         -1          -1
#
# [5 rows x 123 columns]

# %%
Clusters_counts = len(set(Acc_data_lables))
print('Number of clusters: {}'.format(Clusters_counts))
# Out:
# Number of clusters: 22

# %%
# Saving results into SHP
Acc_data.to_file("Shapefile/Clustered_Accidents.shp", encoding="utf-8")

# %%
# Calculating the maximum distance between accidents within each cluster
index_list = []
max_dist = []
eps = []

for radius in [200,300,430,500]:
    
    Clustered_data = Acc_data[Acc_data[f'Labels_{radius}'] != -1]
    
    for name, group in Clustered_data.groupby([f'Labels_{radius}']):    
        max_dist.append(group["geometry"].head(1).values[0].distance(group["geometry"].tail(1).values[0]))
        index_list.append(name)
        eps.append(radius)
# Out:
# C:\Users\sohra\AppData\Local\Temp\ipykernel_16220\3361061844.py:10: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for name, group in Clustered_data.groupby([f'Labels_{radius}']):
# C:\Users\sohra\AppData\Local\Temp\ipykernel_16220\3361061844.py:10: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for name, group in Clustered_data.groupby([f'Labels_{radius}']):
# C:\Users\sohra\AppData\Local\Temp\ipykernel_16220\3361061844.py:10: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for name, group in Clustered_data.groupby([f'Labels_{radius}']):
# C:\Users\sohra\AppData\Local\Temp\ipykernel_16220\3361061844.py:10: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for name, group in Clustered_data.groupby([f'Labels_{radius}']):

# %%
Cluster_Length = pd.DataFrame(list(zip(eps, index_list, max_dist)), columns =['DBSCAN_Eps', 'Cluster_ID', 'Max_Dist'])
Cluster_Length.head()
# Out:
#    DBSCAN_Eps  Cluster_ID    Max_Dist
# 0         200           0  343.864635
# 1         200           1  282.832735
# 2         200           2  207.518076
# 3         200           3  177.098792
# 4         200           4  504.640680

# %%
Cluster_Length.to_excel("Cluster_Lenght.xlsx")

# %%
import pysal
import contextily
import geopandas
import seaborn as sns

# %%
# Runing DBSCAN
clusterer = DBSCAN(eps=200, min_samples=3)
clusterer.fit(Acc_data[['X_', 'Y_']].values)
# Turn labels into a Series
lbls = pd.Series(clusterer.labels_, index=Acc_data.index)
# Setup figure and axis
f, ax = plt.subplots(1, figsize=(20, 20))
# Subset points that are not part of any cluster (noise)
noise = Acc_data.loc[lbls==-1, ['X_', 'Y_']]
# Plot noise in grey
ax.scatter(noise['X_'], noise['Y_'], c='grey', s=5, linewidth=0)
# Plot all points that are not noise in red
ax.scatter(
    Acc_data.loc[Acc_data.index.difference(noise.index), 'X_'],
    Acc_data.loc[Acc_data.index.difference(noise.index), 'Y_'],
    c='red', 
    linewidth=0)
    
# Remove axes
ax.set_axis_off()
# Display the figure
plt.show()
